# %% [markdown]
# Data downloaded from: https://catalog.data.gov/dataset?q=baby+names&sort=score+desc%2C+name+asc

# %% [markdown]
# ## **Importing the names**

# %%
import pandas as pd

# %%
df_1880 = pd.read_csv('Names\yob1880.txt', header=None, names=['Names', 'Gender', 'Count'])
print(df_1880.shape)
df_1880.head()
# Out:
# (2000, 3)
#        Names Gender  Count
# 0       Mary      F   7065
# 1       Anna      F   2604
# 2       Emma      F   2003
# 3  Elizabeth      F   1939
# 4     Minnie      F   1746

# %%
df_1880.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Names   2000 non-null   object
#  1   Gender  2000 non-null   object
#  2   Count   2000 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %% [markdown]
# Merging many data files

# %%
df_1881 = pd.read_csv('Names\yob1881.txt', header=None, names=['Names', 'Gender', 'Count'])
df_1881
# Out:
#           Names Gender  Count
# 0          Mary      F   6919
# 1          Anna      F   2698
# 2          Emma      F   2034
# 3     Elizabeth      F   1852
# 4      Margaret      F   1658
# ...         ...    ...    ...
# 1929     Wiliam      M      5
# 1930     Wilton      M      5
# 1931       Wing      M      5
# 1932       Wood      M      5
# 1933     Wright      M      5
#
# [1934 rows x 3 columns]

# %%
# The index values are not right and we are missing the years of each dataset

df = pd.concat([df_1880, df_1881], axis=0)
df
# Out:
#           Names Gender  Count
# 0          Mary      F   7065
# 1          Anna      F   2604
# 2          Emma      F   2003
# 3     Elizabeth      F   1939
# 4        Minnie      F   1746
# ...         ...    ...    ...
# 1929     Wiliam      M      5
# 1930     Wilton      M      5
# 1931       Wing      M      5
# 1932       Wood      M      5
# 1933     Wright      M      5
#
# [3934 rows x 3 columns]

# %%
df = pd.concat([df_1880, df_1881], axis=0, keys=['1880', '1881'], names=['Year'])
df
# Out:
#                Names Gender  Count
# Year
# 1880 0          Mary      F   7065
#      1          Anna      F   2604
#      2          Emma      F   2003
#      3     Elizabeth      F   1939
#      4        Minnie      F   1746
# ...              ...    ...    ...
# 1881 1929     Wiliam      M      5
#      1930     Wilton      M      5
#      1931       Wing      M      5
#      1932       Wood      M      5
#      1933     Wright      M      5
#
# [3934 rows x 3 columns]

# %%
# Adding the Year column and resetting the index values

df = pd.concat([df_1880, df_1881], axis=0, keys=['1880', '1881'], names=['Year']).droplevel(-1).reset_index()
df
# Out:
#       Year      Names Gender  Count
# 0     1880       Mary      F   7065
# 1     1880       Anna      F   2604
# 2     1880       Emma      F   2003
# 3     1880  Elizabeth      F   1939
# 4     1880     Minnie      F   1746
# ...    ...        ...    ...    ...
# 3929  1881     Wiliam      M      5
# 3930  1881     Wilton      M      5
# 3931  1881       Wing      M      5
# 3932  1881       Wood      M      5
# 3933  1881     Wright      M      5
#
# [3934 rows x 4 columns]

# %% [markdown]
# Merging various files

# %%
years = list(range(1880, 2022))

# %%
dataframe = []

for year in years:
    data = pd.read_csv('Names\yob{}.txt'.format(year), header=None, names=['Names', 'Gender', 'Count'])
    dataframe.append(data)

# %%
dataframe
# Out:
# [          Names Gender  Count
#  0          Mary      F   7065
#  1          Anna      F   2604
#  2          Emma      F   2003
#  3     Elizabeth      F   1939
#  4        Minnie      F   1746
#  ...         ...    ...    ...
#  1995     Woodie      M      5
#  1996     Worthy      M      5
#  1997     Wright      M      5
#  1998       York      M      5
#  1999  Zachariah      M      5
#
#  [2000 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F   6919
#  1          Anna      F   2698
#  2          Emma      F   2034
#  3     Elizabeth      F   1852
#  4      Margaret      F   1658
#  ...         ...    ...    ...
#  1929     Wiliam      M      5
#  1930     Wilton      M      5
#  1931       Wing      M      5
#  1932       Wood      M      5
#  1933     Wright      M      5
#
#  [1934 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F   8148
#  1          Anna      F   3143
#  2          Emma      F   2303
#  3     Elizabeth      F   2186
#  4        Minnie      F   2004
#  ...         ...    ...    ...
#  2122       Wirt      M      5
#  2123    Woodson      M      5
#  2124      Woody      M      5
#  2125     Worley      M      5
#  2126        Zed      M      5
#
#  [2127 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F   8012
#  1          Anna      F   3306
#  2          Emma      F   2367
#  3     Elizabeth      F   2255
#  4        Minnie      F   2035
#  ...         ...    ...    ...
#  2079      Titus      M      5
#  2080      Toney      M      5
#  2081      Verna      M      5
#  2082     Winnie      M      5
#  2083   Winthrop      M      5
#
#  [2084 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F   9217
#  1          Anna      F   3860
#  2          Emma      F   2587
#  3     Elizabeth      F   2549
#  4        Minnie      F   2243
#  ...         ...    ...    ...
#  2292   Williard      M      5
#  2293      Willy      M      5
#  2294    Winston      M      5
#  2295       York      M      5
#  2296  Zachariah      M      5
#
#  [2297 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F   9128
#  1          Anna      F   3994
#  2          Emma      F   2728
#  3     Elizabeth      F   2582
#  4      Margaret      F   2204
#  ...         ...    ...    ...
#  2289     Wallie      M      5
#  2290    Willian      M      5
#  2291       Wirt      M      5
#  2292        Yee      M      5
#  2293        Zeb      M      5
#
#  [2294 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F   9889
#  1          Anna      F   4283
#  2          Emma      F   2764
#  3     Elizabeth      F   2680
#  4        Minnie      F   2372
#  ...         ...    ...    ...
#  2387       Wood      M      5
#  2388      Worth      M      5
#  2389     Wright      M      5
#  2390     Xavier      M      5
#  2391      Yancy      M      5
#
#  [2392 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F   9888
#  1          Anna      F   4227
#  2     Elizabeth      F   2681
#  3          Emma      F   2647
#  4      Margaret      F   2419
#  ...         ...    ...    ...
#  2368    Wheeler      M      5
#  2369    Wilfrid      M      5
#  2370    Wilhelm      M      5
#  2371       Wirt      M      5
#  2372        Zed      M      5
#
#  [2373 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  11754
#  1          Anna      F   4982
#  2     Elizabeth      F   3224
#  3          Emma      F   3087
#  4      Margaret      F   2904
#  ...         ...    ...    ...
#  2646     Vaughn      M      5
#  2647     Vernie      M      5
#  2648       Watt      M      5
#  2649    Winston      M      5
#  2650      Zelma      M      5
#
#  [2651 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  11648
#  1          Anna      F   5062
#  2     Elizabeth      F   3058
#  3      Margaret      F   2917
#  4          Emma      F   2884
#  ...         ...    ...    ...
#  2585     Weldon      M      5
#  2586    Wendell      M      5
#  2587    Wilhelm      M      5
#  2588       Zeke      M      5
#  2589      Zenas      M      5
#
#  [2590 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  12078
#  1          Anna      F   5233
#  2     Elizabeth      F   3112
#  3      Margaret      F   3100
#  4          Emma      F   2980
#  ...         ...    ...    ...
#  2690  Whitfield      M      5
#  2691    Wilhelm      M      5
#  2692    Woodfin      M      5
#  2693     Woodie      M      5
#  2694    Woodson      M      5
#
#  [2695 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  11703
#  1          Anna      F   5099
#  2      Margaret      F   3065
#  3     Elizabeth      F   3059
#  4          Emma      F   2884
#  ...         ...    ...    ...
#  2655    Willian      M      5
#  2656    Winford      M      5
#  2657    Winston      M      5
#  2658      Wyatt      M      5
#  2659      Wylie      M      5
#
#  [2660 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  13172
#  1          Anna      F   5542
#  2     Elizabeth      F   3461
#  3      Margaret      F   3435
#  4          Ruth      F   3290
#  ...         ...    ...    ...
#  2916       Wint      M      5
#  2917     Winton      M      5
#  2918     Worley      M      5
#  2919       York      M      5
#  2920  Zachariah      M      5
#
#  [2921 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  12784
#  1          Anna      F   5695
#  2          Ruth      F   3658
#  3      Margaret      F   3565
#  4     Elizabeth      F   3360
#  ...         ...    ...    ...
#  2826  Whitfield      M      5
#  2827    Whitney      M      5
#  2828     Willia      M      5
#  2829       Wing      M      5
#  2830       Zora      M      5
#
#  [2831 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  13151
#  1          Anna      F   5565
#  2      Margaret      F   3700
#  3         Helen      F   3676
#  4     Elizabeth      F   3425
#  ...         ...    ...    ...
#  2936      Worth      M      5
#  2937     Xavier      M      5
#  2938     Yancey      M      5
#  2939      Yancy      M      5
#  2940      Young      M      5
#
#  [2941 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  13447
#  1          Anna      F   5950
#  2         Helen      F   4023
#  3      Margaret      F   3931
#  4     Elizabeth      F   3603
#  ...         ...    ...    ...
#  3044       Whit      M      5
#  3045    Wilfrid      M      5
#  3046    Wilhelm      M      5
#  3047       Wong      M      5
#  3048        Yee      M      5
#
#  [3049 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  13811
#  1         Anna      F   5860
#  2        Helen      F   4392
#  3     Margaret      F   4050
#  4         Ruth      F   3905
#  ...        ...    ...    ...
#  3086    Worley      M      5
#  3087    Wright      M      5
#  3088    Xavier      M      5
#  3089      York      M      5
#  3090    Zollie      M      5
#
#  [3091 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  13413
#  1         Anna      F   5429
#  2        Helen      F   4519
#  3     Margaret      F   4146
#  4         Ruth      F   3878
#  ...        ...    ...    ...
#  3023    Woodie      M      5
#  3024     Woody      M      5
#  3025    Worley      M      5
#  3026     Worth      M      5
#  3027    Xavier      M      5
#
#  [3028 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  14406
#  1         Anna      F   5773
#  2        Helen      F   5230
#  3     Margaret      F   4696
#  4         Ruth      F   4249
#  ...        ...    ...    ...
#  3259     Wince      M      5
#  3260   Winford      M      5
#  3261      Wing      M      5
#  3262     Wyman      M      5
#  3263       Zed      M      5
#
#  [3264 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  13172
#  1         Anna      F   5115
#  2        Helen      F   5048
#  3     Margaret      F   4249
#  4         Ruth      F   3912
#  ...        ...    ...    ...
#  3037    Waddie      M      5
#  3038   Wilhelm      M      5
#  3039   Winford      M      5
#  3040    Winton      M      5
#  3041     Young      M      5
#
#  [3042 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  16705
#  1        Helen      F   6342
#  2         Anna      F   6114
#  3     Margaret      F   5304
#  4         Ruth      F   4765
#  ...        ...    ...    ...
#  3725     White      M      5
#  3726   Wilhelm      M      5
#  3727  Winifred      M      5
#  3728    Woodie      M      5
#  3729      Zeno      M      5
#
#  [3730 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  13136
#  1        Helen      F   5247
#  2         Anna      F   4923
#  3     Margaret      F   4424
#  4         Ruth      F   3974
#  ...        ...    ...    ...
#  3148     Welby      M      5
#  3149   Westley      M      5
#  3150  Williard      M      5
#  3151     Young      M      5
#  3152       Zeb      M      5
#
#  [3153 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  14486
#  1        Helen      F   5967
#  2         Anna      F   5288
#  3     Margaret      F   5011
#  4         Ruth      F   4384
#  ...        ...    ...    ...
#  3357   Woodrow      M      5
#  3358    Wright      M      5
#  3359     Wyman      M      5
#  3360     Yancy      M      5
#  3361    Zollie      M      5
#
#  [3362 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  14275
#  1        Helen      F   6129
#  2         Anna      F   5098
#  3     Margaret      F   5046
#  4         Ruth      F   4517
#  ...        ...    ...    ...
#  3384      Webb      M      5
#  3385   Wilburt      M      5
#  3386    Worthy      M      5
#  3387     Young      M      5
#  3388    Zollie      M      5
#
#  [3389 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  14961
#  1        Helen      F   6488
#  2         Anna      F   5330
#  3     Margaret      F   5302
#  4         Ruth      F   4900
#  ...        ...    ...    ...
#  3555   Willian      M      5
#  3556    Woodie      M      5
#  3557     Woody      M      5
#  3558    Worley      M      5
#  3559       Yee      M      5
#
#  [3560 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  16067
#  1        Helen      F   6811
#  2     Margaret      F   5690
#  3         Anna      F   5424
#  4         Ruth      F   5068
#  ...        ...    ...    ...
#  3650   Wilburt      M      5
#  3651   Wilfrid      M      5
#  3652   Willian      M      5
#  3653  Winifred      M      5
#  3654   Woodson      M      5
#
#  [3655 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  16370
#  1        Helen      F   7176
#  2     Margaret      F   6096
#  3         Anna      F   5502
#  4         Ruth      F   5140
#  ...        ...    ...    ...
#  3628  Winifred      M      5
#  3629   Winslow      M      5
#  3630      Wray      M      5
#  3631     Wyman      M      5
#  3632    Zeddie      M      5
#
#  [3633 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  17580
#  1        Helen      F   7579
#  2     Margaret      F   6713
#  3         Anna      F   5575
#  4         Ruth      F   5573
#  ...        ...    ...    ...
#  3943      Wray      M      5
#  3944     Wyman      M      5
#  3945       Zeb      M      5
#  3946      Zeke      M      5
#  3947      Zeno      M      5
#
#  [3948 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  18665
#  1        Helen      F   8439
#  2     Margaret      F   6976
#  3         Ruth      F   6180
#  4         Anna      F   5860
#  ...        ...    ...    ...
#  4013   Wilhelm      M      5
#  4014     Wilma      M      5
#  4015    Worthy      M      5
#  4016    Yancey      M      5
#  4017      Zeno      M      5
#
#  [4018 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  19259
#  1        Helen      F   9250
#  2     Margaret      F   7358
#  3         Ruth      F   6509
#  4      Dorothy      F   6253
#  ...        ...    ...    ...
#  4222   Wilfrid      M      5
#  4223     Wilma      M      5
#  4224  Winthrop      M      5
#  4225    Winton      M      5
#  4226   Zygmund      M      5
#
#  [4227 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  22848
#  1        Helen      F  10479
#  2     Margaret      F   8226
#  3      Dorothy      F   7318
#  4         Ruth      F   7212
#  ...        ...    ...    ...
#  4624   Woodson      M      5
#  4625     Woody      M      5
#  4626     Wyman      M      5
#  4627    Yoshio      M      5
#  4628    Zennie      M      5
#
#  [4629 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  24390
#  1        Helen      F  11801
#  2     Margaret      F   9279
#  3      Dorothy      F   8869
#  4         Ruth      F   8003
#  ...        ...    ...    ...
#  4862  Woodford      M      5
#  4863     Woody      M      5
#  4864    Yoshio      M      5
#  4865     Zenas      M      5
#  4866     Zenon      M      5
#
#  [4867 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  32304
#  1        Helen      F  16133
#  2      Dorothy      F  12645
#  3     Margaret      F  12536
#  4         Ruth      F  11280
#  ...        ...    ...    ...
#  6346     Woods      M      5
#  6347      Wray      M      5
#  6348      Wynn      M      5
#  6349      York      M      5
#  6350    Yutaka      M      5
#
#  [6351 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  36642
#  1        Helen      F  18888
#  2      Dorothy      F  14674
#  3     Margaret      F  14486
#  4         Ruth      F  12609
#  ...        ...    ...    ...
#  6963    Yutaka      M      5
#  6964      Zach      M      5
#  6965    Zeddie      M      5
#  6966     Zenas      M      5
#  6967     Zenus      M      5
#
#  [6968 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  45345
#  1        Helen      F  23221
#  2      Dorothy      F  18782
#  3     Margaret      F  17763
#  4         Ruth      F  15839
#  ...        ...    ...    ...
#  7960    Wister      M      5
#  7961   Wofford      M      5
#  7962     Yasuo      M      5
#  7963      Zell      M      5
#  7964    Zenith      M      5
#
#  [7965 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  58187
#  1         Helen      F  30866
#  2       Dorothy      F  25154
#  3      Margaret      F  23054
#  4          Ruth      F  21878
#  ...         ...    ...    ...
#  9352     Yewell      M      5
#  9353  Zachariah      M      5
#  9354      Zelma      M      5
#  9355       Zora      M      5
#  9356    Zygmont      M      5
#
#  [9357 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  61438
#  1        Helen      F  32662
#  2      Dorothy      F  27418
#  3     Margaret      F  24953
#  4         Ruth      F  23189
#  ...        ...    ...    ...
#  9691     Zelma      M      5
#  9692      Zera      M      5
#  9693    Zettie      M      5
#  9694      Ziba      M      5
#  9695      Zina      M      5
#
#  [9696 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  64280
#  1         Helen      F  34251
#  2       Dorothy      F  28852
#  3      Margaret      F  25560
#  4          Ruth      F  23568
#  ...         ...    ...    ...
#  9907  Yoshiharu      M      5
#  9908    Zebulon      M      5
#  9909     Zeddie      M      5
#  9910       Zeke      M      5
#  9911       Zola      M      5
#
#  [9912 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  67366
#  1         Helen      F  36148
#  2       Dorothy      F  32030
#  3      Margaret      F  27139
#  4          Ruth      F  25534
#  ...         ...    ...    ...
#  10393      Zach      M      5
#  10394     Zaven      M      5
#  10395    Zellie      M      5
#  10396    Zelmer      M      5
#  10397     Zenas      M      5
#
#  [10398 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  65837
#  1         Helen      F  33706
#  2       Dorothy      F  31734
#  3      Margaret      F  26238
#  4          Ruth      F  24563
#  ...         ...    ...    ...
#  10364    Zebbie      M      5
#  10365       Zed      M      5
#  10366  Zeferino      M      5
#  10367    Zelmer      M      5
#  10368    Ziggie      M      5
#
#  [10369 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  70982
#  1       Dorothy      F  36643
#  2         Helen      F  35097
#  3      Margaret      F  27994
#  4          Ruth      F  26101
#  ...         ...    ...    ...
#  10751     Zearl      M      5
#  10752  Zeferino      M      5
#  10753      Zeke      M      5
#  10754      Zera      M      5
#  10755   Zygmont      M      5
#
#  [10756 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  73985
#  1       Dorothy      F  39087
#  2         Helen      F  34822
#  3      Margaret      F  28468
#  4          Ruth      F  25784
#  ...         ...    ...    ...
#  10850   Zackary      M      5
#  10851    Zebdee      M      5
#  10852      Zell      M      5
#  10853   Zigmont      M      5
#  10854   Zygmont      M      5
#
#  [10855 rows x 3 columns],
#             Names Gender  Count
#  0           Mary      F  72177
#  1        Dorothy      F  37715
#  2          Helen      F  32510
#  3       Margaret      F  26864
#  4           Ruth      F  23632
#  ...          ...    ...    ...
#  10751  Yoshiyuki      M      5
#  10752      Zenas      M      5
#  10753     Zenith      M      5
#  10754       Zola      M      5
#  10755     Zolton      M      5
#
#  [10756 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  71635
#  1       Dorothy      F  39043
#  2         Helen      F  31486
#  3      Margaret      F  26134
#  4         Betty      F  25990
#  ...         ...    ...    ...
#  10638    Zeddie      M      5
#  10639      Zeke      M      5
#  10640      Zell      M      5
#  10641      Zola      M      5
#  10642    Zolton      M      5
#
#  [10643 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  73535
#  1       Dorothy      F  39998
#  2         Helen      F  31193
#  3         Betty      F  30600
#  4      Margaret      F  26547
#  ...         ...    ...    ...
#  10865  Zaragoza      M      5
#  10866    Zeddie      M      5
#  10867     Zelma      M      5
#  10868    Zelmer      M      5
#  10869    Zenith      M      5
#
#  [10870 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  70587
#  1       Dorothy      F  38570
#  2         Betty      F  32815
#  3         Helen      F  29173
#  4      Margaret      F  24462
#  ...         ...    ...    ...
#  10633     Zenon      M      5
#  10634   Zigmunt      M      5
#  10635    Zolton      M      5
#  10636   Zygmont      M      5
#  10637   Zygmund      M      5
#
#  [10638 rows x 3 columns],
#             Names Gender  Count
#  0           Mary      F  67835
#  1        Dorothy      F  36616
#  2          Betty      F  32962
#  3          Helen      F  26886
#  4       Margaret      F  23073
#  ...          ...    ...    ...
#  10454       Yves      M      5
#  10455  Zachariah      M      5
#  10456        Zan      M      5
#  10457   Zeferino      M      5
#  10458     Zelmer      M      5
#
#  [10459 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  70639
#  1       Dorothy      F  35991
#  2         Betty      F  35425
#  3         Helen      F  25319
#  4      Margaret      F  21964
#  ...         ...    ...    ...
#  10399     Zaven      M      5
#  10400  Zeferino      M      5
#  10401    Zeldon      M      5
#  10402     Zenis      M      5
#  10403   Zygmund      M      5
#
#  [10404 rows x 3 columns],
#             Names Gender  Count
#  0           Mary      F  66873
#  1          Betty      F  36081
#  2        Dorothy      F  33734
#  3          Helen      F  22937
#  4       Margaret      F  20296
#  ...          ...    ...    ...
#  10156      Wynne      M      5
#  10157     Yvonne      M      5
#  10158  Zachariah      M      5
#  10159     Zebbie      M      5
#  10160     Zolton      M      5
#
#  [10161 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  63512
#  1        Betty      F  36676
#  2      Dorothy      F  31477
#  3        Helen      F  20981
#  4     Margaret      F  19209
#  ...        ...    ...    ...
#  9818   Yoshimi      M      5
#  9819   Yoshiro      M      5
#  9820  Zeferino      M      5
#  9821      Zell      M      5
#  9822   Zygmund      M      5
#
#  [9823 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  64151
#  1         Betty      F  38235
#  2       Dorothy      F  30409
#  3         Helen      F  19914
#  4      Margaret      F  18352
#  ...         ...    ...    ...
#  9787       Ynez      M      5
#  9788    Yoshito      M      5
#  9789  Zacharias      M      5
#  9790      Zelma      M      5
#  9791     Zelmer      M      5
#
#  [9792 rows x 3 columns],
#              Names Gender  Count
#  0            Mary      F  60295
#  1           Betty      F  36106
#  2         Dorothy      F  26526
#  3         Barbara      F  21798
#  4            Joan      F  19118
#  ...           ...    ...    ...
#  9293      Worthie      M      5
#  9294  Worthington      M      5
#  9295       Wyllis      M      5
#  9296     Xenophon      M      5
#  9297       Zackie      M      5
#
#  [9298 rows x 3 columns],
#          Names Gender  Count
#  0        Mary      F  59883
#  1       Betty      F  34419
#  2     Barbara      F  26315
#  3     Dorothy      F  24974
#  4        Joan      F  21044
#  ...       ...    ...    ...
#  9377     Yves      M      5
#  9378   Yvonne      M      5
#  9379      Zed      M      5
#  9380    Zelda      M      5
#  9381    Zenas      M      5
#
#  [9382 rows x 3 columns],
#          Names Gender  Count
#  0        Mary      F  55517
#  1       Betty      F  31528
#  2     Barbara      F  26948
#  3     Dorothy      F  22049
#  4        Joan      F  19290
#  ...       ...    ...    ...
#  9007     Zach      M      5
#  9008      Zan      M      5
#  9009   Zannie      M      5
#  9010   Zebbie      M      5
#  9011     Zeke      M      5
#
#  [9012 rows x 3 columns],
#          Names Gender  Count
#  0        Mary      F  56934
#  1       Betty      F  31088
#  2     Barbara      F  29238
#  3     Shirley      F  22844
#  4     Dorothy      F  21283
#  ...       ...    ...    ...
#  9175      Zan      M      5
#  9176   Zeddie      M      5
#  9177    Zenon      M      5
#  9178  Zigmund      M      5
#  9179  Zygmunt      M      5
#
#  [9180 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  55071
#  1      Shirley      F  42357
#  2      Barbara      F  30697
#  3        Betty      F  28674
#  4     Patricia      F  22876
#  ...        ...    ...    ...
#  9033   Winfrey      M      5
#  9034     Yancy      M      5
#  9035    Yazzie      M      5
#  9036  Zaragoza      M      5
#  9037     Zenas      M      5
#
#  [9038 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  54373
#  1      Shirley      F  35162
#  2      Barbara      F  31683
#  3        Betty      F  25869
#  4     Patricia      F  23916
#  ...        ...    ...    ...
#  8888   Willies      M      5
#  8889    Wilman      M      5
#  8890    Wister      M      5
#  8891    Worthy      M      5
#  8892     Wyley      M      5
#
#  [8893 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  55643
#  1      Barbara      F  34914
#  2     Patricia      F  26839
#  3      Shirley      F  26821
#  4        Betty      F  25330
#  ...        ...    ...    ...
#  8942     Wyley      M      5
#  8943      Ynes      M      5
#  8944   Yoshito      M      5
#  8945  Zacarias      M      5
#  8946     Zelma      M      5
#
#  [8947 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  56214
#  1      Barbara      F  39276
#  2     Patricia      F  27556
#  3        Betty      F  25507
#  4      Shirley      F  23767
#  ...        ...    ...    ...
#  9026      Zach      M      5
#  9027    Zannie      M      5
#  9028  Zeferino      M      5
#  9029   Zelbert      M      5
#  9030     Zenon      M      5
#
#  [9031 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  54905
#  1       Barbara      F  37260
#  2      Patricia      F  29707
#  3         Betty      F  23643
#  4       Shirley      F  20447
#  ...         ...    ...    ...
#  8912     Yoshio      M      5
#  8913      Yukio      M      5
#  8914  Zachariah      M      5
#  8915      Zelma      M      5
#  8916      Zenon      M      5
#
#  [8917 rows x 3 columns],
#              Names Gender  Count
#  0            Mary      F  56212
#  1         Barbara      F  36736
#  2        Patricia      F  32665
#  3          Judith      F  22383
#  4           Betty      F  22075
#  ...           ...    ...    ...
#  8956  Worthington      M      5
#  8957        Wynne      M      5
#  8958       Ysabel      M      5
#  8959       Zackie      M      5
#  8960        Zenas      M      5
#
#  [8961 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  58043
#  1      Barbara      F  39539
#  2     Patricia      F  36903
#  3        Carol      F  24185
#  4        Linda      F  23721
#  ...        ...    ...    ...
#  9081   Ygnacio      M      5
#  9082      Yong      M      5
#  9083      Yvon      M      5
#  9084    Zannie      M      5
#  9085      Zell      M      5
#
#  [9086 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  63254
#  1      Barbara      F  44736
#  2     Patricia      F  39459
#  3        Linda      F  31612
#  4        Carol      F  30271
#  ...        ...    ...    ...
#  9418     Wymon      M      5
#  9419    Yancey      M      5
#  9420    Yoshio      M      5
#  9421      Zach      M      5
#  9422       Zed      M      5
#
#  [9423 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  66178
#  1      Barbara      F  43434
#  2     Patricia      F  39622
#  3        Linda      F  38440
#  4        Carol      F  31684
#  ...        ...    ...    ...
#  9403   Wyndell      M      5
#  9404   Yolanda      M      5
#  9405    Ysmael      M      5
#  9406  Zaragoza      M      5
#  9407   Zygmunt      M      5
#
#  [9408 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  62469
#  1      Barbara      F  39197
#  2        Linda      F  38413
#  3     Patricia      F  36878
#  4        Carol      F  30457
#  ...        ...    ...    ...
#  9146     Yancy      M      5
#  9147    Zackie      M      5
#  9148    Zennie      M      5
#  9149      Zeno      M      5
#  9150   Zigmund      M      5
#
#  [9151 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  59282
#  1         Linda      F  41462
#  2       Barbara      F  38273
#  3      Patricia      F  35840
#  4         Carol      F  30387
#  ...         ...    ...    ...
#  9020     Ysmael      M      5
#  9021   Zacarias      M      5
#  9022       Zach      M      5
#  9023  Zachariah      M      5
#  9024      Zenon      M      5
#
#  [9025 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  67471
#  1        Linda      F  52711
#  2     Patricia      F  46298
#  3      Barbara      F  45122
#  4        Carol      F  34283
#  ...        ...    ...    ...
#  9699      Yvon      M      5
#  9700    Yvonne      M      5
#  9701    Zebbie      M      5
#  9702   Zebulon      M      5
#  9703  Zeferino      M      5
#
#  [9704 rows x 3 columns],
#            Names Gender  Count
#  0         Linda      F  99693
#  1          Mary      F  71684
#  2      Patricia      F  51278
#  3       Barbara      F  48796
#  4        Sandra      F  34778
#  ...         ...    ...    ...
#  10366  Zacarias      M      5
#  10367       Zan      M      5
#  10368    Zannie      M      5
#  10369    Zebbie      M      5
#  10370      Zell      M      5
#
#  [10371 rows x 3 columns],
#            Names Gender  Count
#  0         Linda      F  96212
#  1          Mary      F  68601
#  2       Barbara      F  46827
#  3      Patricia      F  46138
#  4         Susan      F  35985
#  ...         ...    ...    ...
#  10236     Yancy      M      5
#  10237   Zachery      M      5
#  10238   Zebulon      M      5
#  10239       Zed      M      5
#  10240      Zell      M      5
#
#  [10241 rows x 3 columns],
#            Names Gender  Count
#  0         Linda      F  91019
#  1          Mary      F  66868
#  2      Patricia      F  46327
#  3       Barbara      F  42600
#  4         Susan      F  37708
#  ...         ...    ...    ...
#  10266   Ygnacio      M      5
#  10267     Yusuf      M      5
#  10268      Yves      M      5
#  10269    Zannie      M      5
#  10270  Zeferino      M      5
#
#  [10271 rows x 3 columns],
#            Names Gender  Count
#  0         Linda      F  80431
#  1          Mary      F  65479
#  2      Patricia      F  47944
#  3       Barbara      F  41553
#  4         Susan      F  38016
#  ...         ...    ...    ...
#  10300   Zachery      M      5
#  10301   Zackary      M      5
#  10302    Zannie      M      5
#  10303      Zeke      M      5
#  10304   Zygmunt      M      5
#
#  [10305 rows x 3 columns],
#            Names Gender  Count
#  0         Linda      F  73977
#  1          Mary      F  65724
#  2      Patricia      F  56444
#  3       Deborah      F  42056
#  4       Barbara      F  40618
#  ...         ...    ...    ...
#  10462   Woodley      M      5
#  10463    Worthy      M      5
#  10464    Yancey      M      5
#  10465   Yisroel      M      5
#  10466   Zackery      M      5
#
#  [10467 rows x 3 columns],
#            Names Gender  Count
#  0         Linda      F  67081
#  1          Mary      F  65624
#  2      Patricia      F  53096
#  3       Deborah      F  49808
#  4         Susan      F  41346
#  ...         ...    ...    ...
#  10641   Woodroe      M      5
#  10642    Wydell      M      5
#  10643      Zach      M      5
#  10644    Zebbie      M      5
#  10645      Zeke      M      5
#
#  [10646 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  64389
#  1         Linda      F  61281
#  2       Deborah      F  52198
#  3      Patricia      F  51019
#  4         Susan      F  44295
#  ...         ...    ...    ...
#  10832  Wwilliam      M      5
#  10833   Wwlliam      M      5
#  10834     Yakov      M      5
#  10835      Yves      M      5
#  10836    Zackie      M      5
#
#  [10837 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  68018
#  1         Linda      F  55374
#  2       Deborah      F  54684
#  3      Patricia      F  49146
#  4         Susan      F  47162
#  ...         ...    ...    ...
#  10979   Yehudah      M      5
#  10980  Yitzchok      M      5
#  10981    Zalman      M      5
#  10982    Zannie      M      5
#  10983    Zeddie      M      5
#
#  [10984 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  63175
#  1       Deborah      F  52320
#  2         Linda      F  51302
#  3         Debra      F  50564
#  4         Susan      F  47421
#  ...         ...    ...    ...
#  11122    Zannie      M      5
#  11123   Zedrick      M      5
#  11124  Zeferino      M      5
#  11125      Zell      M      5
#  11126   Zephery      M      5
#
#  [11127 rows x 3 columns],
#            Names Gender  Count
#  0          Mary      F  61747
#  1         Debra      F  48319
#  2         Linda      F  48080
#  3       Deborah      F  47836
#  4         Susan      F  46569
#  ...         ...    ...    ...
#  11339    Ysmael      M      5
#  11340    Zalmen      M      5
#  11341  Zaragosa      M      5
#  11342     Zenas      M      5
#  11343       Zvi      M      5
#
#  [11344 rows x 3 columns],
#             Names Gender  Count
#  0           Mary      F  61104
#  1          Susan      F  45951
#  2          Linda      F  44505
#  3          Debra      F  42732
#  4          Karen      F  40589
#  ...          ...    ...    ...
#  11562     Yancey      M      5
#  11563        Zac      M      5
#  11564  Zachariah      M      5
#  11565     Zackie      M      5
#  11566     Zonnie      M      5
#
#  [11567 rows x 3 columns],
#             Names Gender  Count
#  0           Mary      F  55852
#  1          Susan      F  45169
#  2          Linda      F  41906
#  3          Karen      F  38466
#  4       Patricia      F  37949
#  ...          ...    ...    ...
#  11524       Wren      M      5
#  11525        Wyn      M      5
#  11526     Ysabel      M      5
#  11527  Zachariah      M      5
#  11528     Zettie      M      5
#
#  [11529 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  54485
#  1        Susan      F  41606
#  2        Linda      F  40408
#  3        Karen      F  36775
#  4        Donna      F  36465
#  ...        ...    ...    ...
#  11761   Ysabel      M      5
#  11762   Zalman      M      5
#  11763   Zebbie      M      5
#  11764  Zebulon      M      5
#  11765  Zyndall      M      5
#
#  [11766 rows x 3 columns],
#          Names Gender  Count
#  0        Mary      F  51476
#  1       Susan      F  39204
#  2       Linda      F  37313
#  3       Karen      F  36380
#  4       Donna      F  34135
#  ...       ...    ...    ...
#  11920   Yates      M      5
#  11921  Ysabel      M      5
#  11922   Yusuf      M      5
#  11923  Zalmen      M      5
#  11924  Zandel      M      5
#
#  [11925 rows x 3 columns],
#           Names Gender  Count
#  0         Mary      F  47682
#  1         Lisa      F  42710
#  2        Susan      F  37526
#  3        Linda      F  35582
#  4        Karen      F  34697
#  ...        ...    ...    ...
#  12180   Yehuda      M      5
#  12181     Yogi      M      5
#  12182     Yvan      M      5
#  12183   Zannie      M      5
#  12184  Zendell      M      5
#
#  [12185 rows x 3 columns],
#             Names Gender  Count
#  0           Lisa      F  46074
#  1           Mary      F  43489
#  2          Susan      F  35739
#  3          Karen      F  35184
#  4          Linda      F  31466
#  ...          ...    ...    ...
#  12209       Yvan      M      5
#  12210        Zac      M      5
#  12211   Zacarias      M      5
#  12212  Zachariah      M      5
#  12213     Zollie      M      5
#
#  [12214 rows x 3 columns],
#             Names Gender  Count
#  0           Lisa      F  56036
#  1           Mary      F  41551
#  2          Susan      F  33997
#  3          Karen      F  32486
#  4          Linda      F  27722
#  ...          ...    ...    ...
#  12281        Wyn      M      5
#  12282     Yaakov      M      5
#  12283        Zac      M      5
#  12284  Zachariah      M      5
#  12285       Zora      M      5
#
#  [12286 rows x 3 columns],
#            Names Gender  Count
#  0          Lisa      F  54269
#  1          Mary      F  40984
#  2         Susan      F  31516
#  3         Karen      F  30250
#  4      Patricia      F  26085
#  ...         ...    ...    ...
#  12392       Zac      M      5
#  12393    Zalman      M      5
#  12394    Zedric      M      5
#  12395      Zeno      M      5
#  12396      Zina      M      5
#
#  [12397 rows x 3 columns],
#            Names Gender  Count
#  0          Lisa      F  60271
#  1          Mary      F  34271
#  2         Karen      F  32870
#  3      Kimberly      F  28835
#  4         Susan      F  26328
#  ...         ...    ...    ...
#  11950    Willem      M      5
#  11951   Winferd      M      5
#  11952    Worley      M      5
#  11953    Worthy      M      5
#  11954  Wwilliam      M      5
#
#  [11955 rows x 3 columns],
#            Names Gender  Count
#  0          Lisa      F  56918
#  1      Kimberly      F  32232
#  2          Mary      F  28887
#  3      Michelle      F  27155
#  4         Karen      F  25448
#  ...         ...    ...    ...
#  12154   Yarnell      M      5
#  12155   Yolanda      M      5
#  12156      Yvon      M      5
#  12157    Zalman      M      5
#  12158   Zygmunt      M      5
#
#  [12159 rows x 3 columns],
#            Names Gender  Count
#  0          Lisa      F  52434
#  1      Kimberly      F  33101
#  2      Michelle      F  30824
#  3          Mary      F  25316
#  4         Susan      F  22264
#  ...         ...    ...    ...
#  12399  Zbigniew      M      5
#  12400   Zebedee      M      5
#  12401      Zeno      M      5
#  12402     Zenon      M      5
#  12403       Zev      M      5
#
#  [12404 rows x 3 columns],
#            Names Gender  Count
#  0          Lisa      F  49537
#  1      Michelle      F  33223
#  2      Kimberly      F  31909
#  3      Jennifer      F  26852
#  4       Melissa      F  21727
#  ...         ...    ...    ...
#  12933     Wynne      M      5
#  12934      Zain      M      5
#  12935    Zalman      M      5
#  12936    Zavier      M      5
#  12937   Zedrick      M      5
#
#  [12938 rows x 3 columns],
#            Names Gender  Count
#  0          Lisa      F  45027
#  1      Michelle      F  34318
#  2      Jennifer      F  33701
#  3      Kimberly      F  33083
#  4       Melissa      F  23023
#  ...         ...    ...    ...
#  13746    Zalmen      M      5
#  13747   Zedrick      M      5
#  13748       Zen      M      5
#  13749     Zenas      M      5
#  13750    Zolton      M      5
#
#  [13751 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  46153
#  1          Lisa      F  38964
#  2      Kimberly      F  34137
#  3      Michelle      F  34049
#  4           Amy      F  25211
#  ...         ...    ...    ...
#  14777      Zaid      M      5
#  14778    Zalmen      M      5
#  14779    Zavier      M      5
#  14780   Zebulon      M      5
#  14781       Zon      M      5
#
#  [14782 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  56779
#  1      Michelle      F  33159
#  2          Lisa      F  32912
#  3      Kimberly      F  30703
#  4           Amy      F  26238
#  ...         ...    ...    ...
#  15293    Zawdie      M      5
#  15294       Zel      M      5
#  15295      Zeno      M      5
#  15296     Zenon      M      5
#  15297   Zigmond      M      5
#
#  [15298 rows x 3 columns],
#             Names Gender  Count
#  0       Jennifer      F  63603
#  1       Michelle      F  29289
#  2           Lisa      F  27548
#  3       Kimberly      F  26284
#  4            Amy      F  25874
#  ...          ...    ...    ...
#  15411     Yvonne      M      5
#  15412   Zacarias      M      5
#  15413  Zacharian      M      5
#  15414        Zed      M      5
#  15415  Zimbalist      M      5
#
#  [15416 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  62447
#  1           Amy      F  26964
#  2      Michelle      F  26934
#  3      Kimberly      F  23532
#  4          Lisa      F  22672
#  ...         ...    ...    ...
#  15681       Zan      M      5
#  15682   Zerrick      M      5
#  15683      Zeus      M      5
#  15684      Zion      M      5
#  15685      Zuri      M      5
#
#  [15686 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  63112
#  1           Amy      F  29565
#  2      Michelle      F  25828
#  3       Heather      F  23181
#  4        Angela      F  22804
#  ...         ...    ...    ...
#  16244      Yero      M      5
#  16245     Yonah      M      5
#  16246   Yonatan      M      5
#  16247    Yousef      M      5
#  16248     Zenas      M      5
#
#  [16249 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  58187
#  1           Amy      F  32253
#  2       Heather      F  24301
#  3       Melissa      F  24169
#  4        Angela      F  23360
#  ...         ...    ...    ...
#  16945  Zederick      M      5
#  16946    Zedric      M      5
#  16947     Zenas      M      5
#  16948    Zollie      M      5
#  16949     Zoran      M      5
#
#  [16950 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  59473
#  1           Amy      F  31339
#  2       Melissa      F  25096
#  3       Heather      F  24191
#  4        Angela      F  22039
#  ...         ...    ...    ...
#  17395  Zacharie      M      5
#  17396   Zebulun      M      5
#  17397    Zedric      M      5
#  17398       Zee      M      5
#  17399     Zenas      M      5
#
#  [17400 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  58966
#  1       Melissa      F  26881
#  2           Amy      F  26732
#  3       Jessica      F  24846
#  4       Heather      F  23776
#  ...         ...    ...    ...
#  18178     Ziyad      M      5
#  18179       Zoe      M      5
#  18180    Zollie      M      5
#  18181      Zuri      M      5
#  18182    Zuriel      M      5
#
#  [18183 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  56320
#  1       Melissa      F  28327
#  2       Jessica      F  26103
#  3           Amy      F  23212
#  4       Heather      F  22273
#  ...         ...    ...    ...
#  18229       Zan      M      5
#  18230    Zerick      M      5
#  18231    Zikomo      M      5
#  18232    Zollie      M      5
#  18233       Zon      M      5
#
#  [18234 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  56719
#  1       Melissa      F  34054
#  2        Amanda      F  31928
#  3       Jessica      F  27782
#  4           Amy      F  21612
#  ...         ...    ...    ...
#  19038       Zan      M      5
#  19039       Zed      M      5
#  19040   Zeeshan      M      5
#  19041   Zerrick      M      5
#  19042       Zon      M      5
#
#  [19043 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  58381
#  1        Amanda      F  35814
#  2       Jessica      F  33924
#  3       Melissa      F  31637
#  4         Sarah      F  25759
#  ...         ...    ...    ...
#  19452    Zedric      M      5
#  19453      Zell      M      5
#  19454     Zenas      M      5
#  19455   Zhivago      M      5
#  19456       Zoe      M      5
#
#  [19457 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  57048
#  1       Jessica      F  42537
#  2        Amanda      F  34375
#  3         Sarah      F  28172
#  4       Melissa      F  28003
#  ...         ...    ...    ...
#  19478   Zerrick      M      5
#  19479     Zeyad      M      5
#  19480  Zimbabwe      M      5
#  19481    Zoltan      M      5
#  19482    Zuriel      M      5
#
#  [19483 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  57119
#  1       Jessica      F  45456
#  2        Amanda      F  34215
#  3         Sarah      F  28488
#  4       Melissa      F  25868
#  ...         ...    ...    ...
#  19695      Zaki      M      5
#  19696   Zebulin      M      5
#  19697  Zedekiah      M      5
#  19698     Zubin      M      5
#  19699    Zuriel      M      5
#
#  [19700 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  54349
#  1       Jessica      F  45280
#  2        Amanda      F  33755
#  3        Ashley      F  33296
#  4         Sarah      F  27232
#  ...         ...    ...    ...
#  19407  Zebediah      M      5
#  19408   Zebulan      M      5
#  19409       Zef      M      5
#  19410     Zenas      M      5
#  19411     Zoran      M      5
#
#  [19412 rows x 3 columns],
#            Names Gender  Count
#  0      Jennifer      F  50561
#  1       Jessica      F  45858
#  2        Ashley      F  38774
#  3        Amanda      F  33910
#  4         Sarah      F  25884
#  ...         ...    ...    ...
#  19505      Zayd      M      5
#  19506   Zebedee      M      5
#  19507   Zebulan      M      5
#  19508      Zeno      M      5
#  19509    Zeshan      M      5
#
#  [19510 rows x 3 columns],
#            Names Gender  Count
#  0       Jessica      F  48347
#  1        Ashley      F  47007
#  2      Jennifer      F  42659
#  3        Amanda      F  39056
#  4         Sarah      F  24882
#  ...         ...    ...    ...
#  20086      Zeus      M      5
#  20087       Zia      M      5
#  20088       Ziv      M      5
#  20089     Ziyad      M      5
#  20090    Zubair      M      5
#
#  [20091 rows x 3 columns],
#            Names Gender  Count
#  0       Jessica      F  52682
#  1        Ashley      F  49674
#  2        Amanda      F  40534
#  3      Jennifer      F  36184
#  4         Sarah      F  28162
#  ...         ...    ...    ...
#  20655       Zia      M      5
#  20656       Zoe      M      5
#  20657     Zoilo      M      5
#  20658    Zollie      M      5
#  20659    Zubair      M      5
#
#  [20660 rows x 3 columns],
#            Names Gender  Count
#  0       Jessica      F  55997
#  1        Ashley      F  54855
#  2        Amanda      F  41788
#  3      Jennifer      F  32704
#  4         Sarah      F  27894
#  ...         ...    ...    ...
#  21406     Zakry      M      5
#  21407    Zander      M      5
#  21408   Zebulen      M      5
#  21409      Zeus      M      5
#  21410     Zubin      M      5
#
#  [21411 rows x 3 columns],
#            Names Gender  Count
#  0       Jessica      F  51549
#  1        Ashley      F  49968
#  2        Amanda      F  39458
#  3         Sarah      F  28370
#  4      Jennifer      F  27892
#  ...         ...    ...    ...
#  22367     Ziggy      M      5
#  22368    Zishan      M      5
#  22369       Zoe      M      5
#  22370      Zong      M      5
#  22371     Zubin      M      5
#
#  [22372 rows x 3 columns],
#            Names Gender  Count
#  0       Jessica      F  47890
#  1        Ashley      F  47588
#  2      Brittany      F  37791
#  3        Amanda      F  36830
#  4         Sarah      F  27793
#  ...         ...    ...    ...
#  23770   Zebulin      M      5
#  23771       Zek      M      5
#  23772       Zen      M      5
#  23773      Zeno      M      5
#  23774     Zerek      M      5
#
#  [23775 rows x 3 columns],
#            Names Gender  Count
#  0       Jessica      F  46481
#  1        Ashley      F  45560
#  2      Brittany      F  36536
#  3        Amanda      F  34409
#  4      Samantha      F  25868
#  ...         ...    ...    ...
#  24712      Zeus      M      5
#  24713     Ziyad      M      5
#  24714     Zoilo      M      5
#  24715     Zoran      M      5
#  24716       Zvi      M      5
#
#  [24717 rows x 3 columns],
#            Names Gender  Count
#  0        Ashley      F  43481
#  1       Jessica      F  43398
#  2      Brittany      F  29091
#  3        Amanda      F  28893
#  4      Samantha      F  25647
#  ...         ...    ...    ...
#  25110      Zeev      M      5
#  25111      Zein      M      5
#  25112    Zerick      M      5
#  25113    Zeshan      M      5
#  25114    Zuhair      M      5
#
#  [25115 rows x 3 columns],
#            Names Gender  Count
#  0        Ashley      F  38457
#  1       Jessica      F  38358
#  2        Amanda      F  25035
#  3      Brittany      F  24982
#  4         Sarah      F  24635
#  ...         ...    ...    ...
#  25423     Ziyad      M      5
#  25424    Zohrab      M      5
#  25425     Zubin      M      5
#  25426    Zuhair      M      5
#  25427     Zyair      M      5
#
#  [25428 rows x 3 columns],
#            Names Gender  Count
#  0       Jessica      F  34990
#  1        Ashley      F  34850
#  2         Sarah      F  24254
#  3      Samantha      F  23669
#  4         Emily      F  23593
#  ...         ...    ...    ...
#  25962     Ziare      M      5
#  25963    Zishan      M      5
#  25964     Zoheb      M      5
#  25965      Zuri      M      5
#  25966       Zvi      M      5
#
#  [25967 rows x 3 columns],
#            Names Gender  Count
#  0       Jessica      F  32120
#  1        Ashley      F  30282
#  2         Emily      F  24151
#  3      Samantha      F  22824
#  4         Sarah      F  22293
#  ...         ...    ...    ...
#  25993    Zedric      M      5
#  25994       Zef      M      5
#  25995      Zoey      M      5
#  25996      Zong      M      5
#  25997    Zuhair      M      5
#
#  [25998 rows x 3 columns],
#            Names Gender  Count
#  0       Jessica      F  27938
#  1        Ashley      F  26601
#  2         Emily      F  24380
#  3      Samantha      F  21644
#  4         Sarah      F  21392
#  ...         ...    ...    ...
#  26075     Zerek      M      5
#  26076      Zhen      M      5
#  26077     Ziggy      M      5
#  26078    Zuberi      M      5
#  26079      Zyon      M      5
#
#  [26080 rows x 3 columns],
#            Names Gender  Count
#  0         Emily      F  25151
#  1       Jessica      F  24201
#  2        Ashley      F  23679
#  3         Sarah      F  21040
#  4      Samantha      F  20551
#  ...         ...    ...    ...
#  26419       Zhi      M      5
#  26420  Zildjian      M      5
#  26421     Zishe      M      5
#  26422     Zoran      M      5
#  26423     Zyler      M      5
#
#  [26424 rows x 3 columns],
#           Names Gender  Count
#  0        Emily      F  25735
#  1      Jessica      F  21044
#  2       Ashley      F  20895
#  3        Sarah      F  20712
#  4       Hannah      F  20594
#  ...        ...    ...    ...
#  26967    Zhane      M      5
#  26968     Zian      M      5
#  26969     Ziar      M      5
#  26970   Zohair      M      5
#  26971    Zohar      M      5
#
#  [26972 rows x 3 columns],
#            Names Gender  Count
#  0         Emily      F  26185
#  1        Hannah      F  21375
#  2      Samantha      F  20194
#  3         Sarah      F  19892
#  4        Ashley      F  19874
#  ...         ...    ...    ...
#  27902    Zayvon      M      5
#  27903    Ziaire      M      5
#  27904  Zildjian      M      5
#  27905    Zykeem      M      5
#  27906    Zyquan      M      5
#
#  [27907 rows x 3 columns],
#            Names Gender  Count
#  0         Emily      F  26539
#  1        Hannah      F  21677
#  2        Alexis      F  19234
#  3         Sarah      F  19112
#  4      Samantha      F  19040
#  ...         ...    ...    ...
#  28550     Zyier      M      5
#  28551    Zyquan      M      5
#  28552    Zyquez      M      5
#  28553     Zyron      M      5
#  28554   Zyshaun      M      5
#
#  [28555 rows x 3 columns],
#           Names Gender  Count
#  0        Emily      F  25957
#  1       Hannah      F  23085
#  2      Madison      F  19968
#  3       Ashley      F  17997
#  4        Sarah      F  17708
#  ...        ...    ...    ...
#  29771     Zeph      M      5
#  29772    Zeven      M      5
#  29773    Ziggy      M      5
#  29774       Zo      M      5
#  29775    Zyier      M      5
#
#  [29776 rows x 3 columns],
#           Names Gender  Count
#  0        Emily      F  25058
#  1      Madison      F  22166
#  2       Hannah      F  20719
#  3       Ashley      F  16529
#  4       Alexis      F  16402
#  ...        ...    ...    ...
#  30276     Zyad      M      5
#  30277    Zyere      M      5
#  30278    Zykel      M      5
#  30279    Zyrek      M      5
#  30280  Zyshaun      M      5
#
#  [30281 rows x 3 columns],
#           Names Gender  Count
#  0        Emily      F  24468
#  1      Madison      F  21773
#  2       Hannah      F  18825
#  3         Emma      F  16550
#  4       Alexis      F  15636
#  ...        ...    ...    ...
#  30563    Zimri      M      5
#  30564    Zoran      M      5
#  30565     Zyen      M      5
#  30566    Zylan      M      5
#  30567    Zyonn      M      5
#
#  [30568 rows x 3 columns],
#           Names Gender  Count
#  0        Emily      F  25691
#  1         Emma      F  22711
#  2      Madison      F  20200
#  3       Hannah      F  17637
#  4       Olivia      F  16153
#  ...        ...    ...    ...
#  31186   Zorion      M      5
#  31187  Zxavian      M      5
#  31188     Zyad      M      5
#  31189   Zykeem      M      5
#  31190   Zysean      M      5
#
#  [31191 rows x 3 columns],
#            Names Gender  Count
#  0         Emily      F  25039
#  1          Emma      F  21614
#  2       Madison      F  20627
#  3        Olivia      F  16107
#  4        Hannah      F  15609
#  ...         ...    ...    ...
#  32050     Zykee      M      5
#  32051  Zymarion      M      5
#  32052    Zymeir      M      5
#  32053    Zyrell      M      5
#  32054     Zyron      M      5
#
#  [32055 rows x 3 columns],
#             Names Gender  Count
#  0          Emily      F  23948
#  1           Emma      F  20349
#  2        Madison      F  19572
#  3        Abigail      F  15753
#  4         Olivia      F  15698
#  ...          ...    ...    ...
#  32551    Zymiere      M      5
#  32552     Zyrell      M      5
#  32553     Zyrian      M      5
#  32554     Zyshon      M      5
#  32555  Zytavious      M      5
#
#  [32556 rows x 3 columns],
#              Names Gender  Count
#  0           Emily      F  21409
#  1            Emma      F  19124
#  2         Madison      F  18629
#  3        Isabella      F  18227
#  4             Ava      F  16941
#  ...           ...    ...    ...
#  34092      Zymire      M      5
#  34093  Zyquavious      M      5
#  34094      Zyrell      M      5
#  34095     Zyshaun      M      5
#  34096     Zyshawn      M      5
#
#  [34097 rows x 3 columns],
#              Names Gender  Count
#  0           Emily      F  19358
#  1        Isabella      F  19140
#  2            Emma      F  18377
#  3             Ava      F  18053
#  4         Madison      F  17963
#  ...           ...    ...    ...
#  34960       Zylin      M      5
#  34961       Zyonn      M      5
#  34962   Zyquarius      M      5
#  34963  Zyquavious      M      5
#  34964      Zyrese      M      5
#
#  [34965 rows x 3 columns],
#             Names Gender  Count
#  0           Emma      F  18821
#  1       Isabella      F  18624
#  2          Emily      F  17439
#  3         Olivia      F  17085
#  4            Ava      F  17044
#  ...          ...    ...    ...
#  35083     Zymire      M      5
#  35084  Zyquarius      M      5
#  35085  Zyquavion      M      5
#  35086     Zyrell      M      5
#  35087      Zyren      M      5
#
#  [35088 rows x 3 columns],
#             Names Gender  Count
#  0       Isabella      F  22312
#  1           Emma      F  17906
#  2         Olivia      F  17438
#  3         Sophia      F  16948
#  4            Ava      F  15873
#  ...          ...    ...    ...
#  34717  Zyquarius      M      5
#  34718      Zyran      M      5
#  34719    Zyreion      M      5
#  34720     Zyrian      M      5
#  34721     Zyvion      M      5
#
#  [34722 rows x 3 columns],
#             Names Gender  Count
#  0       Isabella      F  22925
#  1         Sophia      F  20648
#  2           Emma      F  17354
#  3         Olivia      F  17030
#  4            Ava      F  15436
#  ...          ...    ...    ...
#  34084    Zymaire      M      5
#  34085     Zyonne      M      5
#  34086  Zyquarius      M      5
#  34087      Zyran      M      5
#  34088      Zzyzx      M      5
#
#  [34089 rows x 3 columns],
#            Names Gender  Count
#  0        Sophia      F  21855
#  1      Isabella      F  19923
#  2          Emma      F  18811
#  3        Olivia      F  17328
#  4           Ava      F  15507
#  ...         ...    ...    ...
#  33918     Zylar      M      5
#  33919     Zylas      M      5
#  33920     Zyran      M      5
#  33921   Zyshawn      M      5
#  33922  Zytavion      M      5
#
#  [33923 rows x 3 columns],
#             Names Gender  Count
#  0         Sophia      F  22322
#  1           Emma      F  20960
#  2       Isabella      F  19119
#  3         Olivia      F  17323
#  4            Ava      F  15542
#  ...          ...    ...    ...
#  33758      Zylin      M      5
#  33759     Zymari      M      5
#  33760      Zyrin      M      5
#  33761      Zyrus      M      5
#  33762  Zytaevius      M      5
#
#  [33763 rows x 3 columns],
#            Names Gender  Count
#  0        Sophia      F  21236
#  1          Emma      F  20954
#  2        Olivia      F  18440
#  3      Isabella      F  17657
#  4           Ava      F  15259
#  ...         ...    ...    ...
#  33308     Zyere      M      5
#  33309     Zylar      M      5
#  33310    Zymari      M      5
#  33311    Zymeer      M      5
#  33312     Zyree      M      5
#
#  [33313 rows x 3 columns],
#            Names Gender  Count
#  0          Emma      F  20949
#  1        Olivia      F  19826
#  2        Sophia      F  18633
#  3      Isabella      F  17115
#  4           Ava      F  15715
#  ...         ...    ...    ...
#  33275    Zykeem      M      5
#  33276    Zymeer      M      5
#  33277   Zymiere      M      5
#  33278     Zyran      M      5
#  33279     Zyrin      M      5
#
#  [33280 rows x 3 columns],
#            Names Gender  Count
#  0          Emma      F  20468
#  1        Olivia      F  19713
#  2        Sophia      F  17437
#  3           Ava      F  16391
#  4      Isabella      F  15641
#  ...         ...    ...    ...
#  33151    Zykell      M      5
#  33152    Zyking      M      5
#  33153     Zykir      M      5
#  33154     Zyrus      M      5
#  33155      Zyus      M      5
#
#  [33156 rows x 3 columns],
#            Names Gender  Count
#  0          Emma      F  19531
#  1        Olivia      F  19386
#  2           Ava      F  16329
#  3        Sophia      F  16159
#  4      Isabella      F  14837
#  ...         ...    ...    ...
#  33038    Zolton      M      5
#  33039    Zurich      M      5
#  33040    Zyahir      M      5
#  33041      Zyel      M      5
#  33042     Zylyn      M      5
#
#  [33043 rows x 3 columns],
#            Names Gender  Count
#  0          Emma      F  19847
#  1        Olivia      F  18753
#  2           Ava      F  15998
#  3      Isabella      F  15222
#  4        Sophia      F  14910
#  ...         ...    ...    ...
#  32643    Zykeem      M      5
#  32644     Zylin      M      5
#  32645     Zylis      M      5
#  32646     Zylyn      M      5
#  32647     Zyrie      M      5
#
#  [32648 rows x 3 columns],
#            Names Gender  Count
#  0          Emma      F  18786
#  1        Olivia      F  18022
#  2           Ava      F  14998
#  3      Isabella      F  14538
#  4        Sophia      F  13984
#  ...         ...    ...    ...
#  32191     Zylas      M      5
#  32192     Zyran      M      5
#  32193     Zyrie      M      5
#  32194     Zyron      M      5
#  32195     Zzyzx      M      5
#
#  [32196 rows x 3 columns],
#            Names Gender  Count
#  0        Olivia      F  18534
#  1          Emma      F  17176
#  2           Ava      F  14515
#  3        Sophia      F  13769
#  4      Isabella      F  13360
#  ...         ...    ...    ...
#  32068    Zyheem      M      5
#  32069     Zykel      M      5
#  32070    Zyking      M      5
#  32071       Zyn      M      5
#  32072     Zyran      M      5
#
#  [32073 rows x 3 columns],
#             Names Gender  Count
#  0         Olivia      F  17641
#  1           Emma      F  15656
#  2            Ava      F  13160
#  3      Charlotte      F  13065
#  4         Sophia      F  13036
#  ...          ...    ...    ...
#  31448     Zykell      M      5
#  31449      Zylus      M      5
#  31450     Zymari      M      5
#  31451        Zyn      M      5
#  31452      Zyran      M      5
#
#  [31453 rows x 3 columns],
#             Names Gender  Count
#  0         Olivia      F  17728
#  1           Emma      F  15433
#  2      Charlotte      F  13285
#  3         Amelia      F  12952
#  4            Ava      F  12759
#  ...          ...    ...    ...
#  31532     Zyeire      M      5
#  31533       Zyel      M      5
#  31534      Zyian      M      5
#  31535      Zylar      M      5
#  31536        Zyn      M      5
#
#  [31537 rows x 3 columns]]

# %%
len(dataframe)
# Out:
# 142

# %%
df = pd.concat(dataframe, axis=0, keys=years, names=['Year']).droplevel(-1).reset_index()
df
# Out:
#          Year      Names Gender  Count
# 0        1880       Mary      F   7065
# 1        1880       Anna      F   2604
# 2        1880       Emma      F   2003
# 3        1880  Elizabeth      F   1939
# 4        1880     Minnie      F   1746
# ...       ...        ...    ...    ...
# 2052776  2021     Zyeire      M      5
# 2052777  2021       Zyel      M      5
# 2052778  2021      Zyian      M      5
# 2052779  2021      Zylar      M      5
# 2052780  2021        Zyn      M      5
#
# [2052781 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2052781 entries, 0 to 2052780
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Year    int64
#  1   Names   object
#  2   Gender  object
#  3   Count   int64
# dtypes: int64(2), object(2)
# memory usage: 62.6+ MB

# %%
df.to_csv('US_baby_names.csv', index=False)

# %%
pd.read_csv('US_baby_names.csv')
# Out:
#          Year      Names Gender  Count
# 0        1880       Mary      F   7065
# 1        1880       Anna      F   2604
# 2        1880       Emma      F   2003
# 3        1880  Elizabeth      F   1939
# 4        1880     Minnie      F   1746
# ...       ...        ...    ...    ...
# 2052776  2021     Zyeire      M      5
# 2052777  2021       Zyel      M      5
# 2052778  2021      Zyian      M      5
# 2052779  2021      Zylar      M      5
# 2052780  2021        Zyn      M      5
#
# [2052781 rows x 4 columns]
